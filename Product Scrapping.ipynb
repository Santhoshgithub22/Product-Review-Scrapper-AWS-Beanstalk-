# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install flask_cors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from flask import Flask, render_template, request, jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
searchstring = "iphone11"

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + searchstring

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %% [markdown]
# now we can able to get iphone11
# now what we want is? The next operation we are supposed to do is click
#
# Now I want to click one of these phone.
#
# inside on that page I will be able to get a reviews and so on.

# %%
# If my python will hit this particular url
# with the help off uReq we can hit any url in this world.

uclient = uReq(flipkart_url)

# %%
uclient

# %% [markdown]
# What this output (uclient.read()) actually says, if we go any webpage and right click select view page source.
#
# After that we will able to get html file, java script and so on.
#
# That's what we got on uclient.read() output.

# %%
flipkartpage = uclient.read()

# %%
flipkart_html = bs(flipkartpage, "html.parser")
#whatever we have a html data it will just beautify it littlebit

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# #### Now How I will be able to click from the code

# %% [markdown]
# Just try to press F12
#
# Inside this window we will able to see small arrow button in very first place and click on this element and click that arrow button.
#
# Here everything is possible to inspect.
#
# Whatever you can see on website we can scrap it.
#
# It is possible to scrape each and everything.

# %% [markdown]
# #### In href we can able to get the hyperlink of entire mobile <a class la irundhuchu.

# %% [markdown]
# I copied this href and going to append it in a flipkart url

# %%
'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=d5d0fbb4-8881-46b8-a102-3e5de54e1263.MOBFWQ6B7KKRXDDS.SEARCH&ppt=sp&ppn=sp&ssid=h1fdq1sb0g0000001678522515017&qH=d6db477051465f9a'
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=d5d0fbb4-8881-46b8-a102-3e5de54e1263.MOBFWQ6B7KKRXDDS.SEARCH&ppt=sp&ppn=sp&ssid=h1fdq1sb0g0000001678522515017&qH=d6db477051465f9a'

# %% [markdown]
# # But the best part is flipkart_html

# %%
# But the best part is flipkart_html

# Na mela edutha link already idhula irukku, but the problem is its not in a readable method

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.findAll("div", {"class" : "_1AtVbE col-12-12"})

# %%
len(bigboxes)  # there are 30 mobile phones I am able to find in one page
# Out:
# 30

# %% [markdown]
# #### What is my Idea?
#
#     My Idea is to go to the particular tag where the all phone details are available.

# %%
box = bigboxes[2]

#This is showing me one single record for one single phone.

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBFWQ6BVWVEH3XE" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&amp;lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=67c2a3d3-ceb1-4174-9084-5bf858760286.MOBFWQ6BVWVEH3XE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=vy1qn3jn4w0000001678517394470&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (White, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/k/y/d/iphone-11-256-u-mwm82hn-a-apple-0-original-imafkg25mhaztxns.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDk
# ...

# %% [markdown]
# Inside this I want to try to find the href.
#
# Why I want to find href.?
#
#     Because It will hold all of my details for my one particular mobile

# %%
box.div
# Out:
# <div class="_13oc-S"><div data-id="MOBFWQ6BVWVEH3XE" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&amp;lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=67c2a3d3-ceb1-4174-9084-5bf858760286.MOBFWQ6BVWVEH3XE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=vy1qn3jn4w0000001678517394470&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (White, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/k/y/d/iphone-11-256-u-mwm82hn-a-apple-0-original-imafkg25mhaztxns.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" read
# ...

# %%
box.div.div
# Out:
# <div data-id="MOBFWQ6BVWVEH3XE" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&amp;lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=67c2a3d3-ceb1-4174-9084-5bf858760286.MOBFWQ6BVWVEH3XE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=vy1qn3jn4w0000001678517394470&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (White, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/k/y/d/iphone-11-256-u-mwm82hn-a-apple-0-original-imafkg25mhaztxns.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbo
# ...

# %%
# Here Now, I am able to see a, inside a I am able to see href.
box.div.div.div
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&amp;lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=67c2a3d3-ceb1-4174-9084-5bf858760286.MOBFWQ6BVWVEH3XE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=vy1qn3jn4w0000001678517394470&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (White, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/k/y/d/iphone-11-256-u-mwm82hn-a-apple-0-original-imafkg25mhaztxns.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><labe
# ...

# %% [markdown]
# # Now I will be going to attach the href in flipkart URL, then only I will be able to get the entire hyperlink of the particular phone.

# %%
box.div.div.div.a['href'] #this is the url now I want to append with flipkart url
# Out:
# '/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=67c2a3d3-ceb1-4174-9084-5bf858760286.MOBFWQ6BVWVEH3XE.SEARCH&ppt=None&ppn=None&ssid=vy1qn3jn4w0000001678517394470&qH=d6db477051465f9a'

# %%
"https://www.flipkart.com" + box.div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=67c2a3d3-ceb1-4174-9084-5bf858760286.MOBFWQ6BVWVEH3XE.SEARCH&ppt=None&ppn=None&ssid=vy1qn3jn4w0000001678517394470&qH=d6db477051465f9a'

# %%
productlink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=67c2a3d3-ceb1-4174-9084-5bf858760286.MOBFWQ6BVWVEH3XE.SEARCH&ppt=None&ppn=None&ssid=vy1qn3jn4w0000001678517394470&qH=d6db477051465f9a'

# %% [markdown]
# # Now I am this page, I want to review on this page.

# %%
productreq = requests.get(productlink) 

#I just try to get only one product, so when I am using a loop i will be able to get all of details in a particular pages

# %%
productreq
# Out:
# <Response [200]>

# %%
productreq.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.a47a6a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %% [markdown]
# # Once I am get the html data, Then I should use beautiful soup

# %%
prod_html = bs(productreq.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # Now I am in prod html page, now what I will find out?
#
#     I want to find out the review.

# %%
comment_box = prod_html.find_all("div", {"class" : "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[1]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Perfect product!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202006/blobio-imr-202006_1e75c4c6c74e43758464bf1ccee95656.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202006/blobio-imr-202006_60d4b624faf24ee8a136c3e941fad396.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-
# ...

# %%
comment_box[1].div.div.div.div.text #we got one rating but how can we got complete rating
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19884/2621339938.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[1].div.div.find_all("div", {"class" : ""})
# Out:
# [<div><div class="">Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .</div>,
#  <div></div>]

# %%
comment_box[1].div.div.find_all("div", {"class" : ""})[0]
# Out:
# <div><div class="">Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .</div><span class="_1H-bmy"><span>READ MORE</span></span></div>

# %%
comment_box[1].div.div.find_all("div", {"class" : ""})[0].div
# Out:
# <div class="">Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .</div>

# %%
comment_box[1].div.div.find_all("div", {"class" : ""})[0].div.text
# Out:
# 'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .'

# %%
for i in comment_box:
    print(i.div.div.find_all("div", {"class" : ""})[0].div.text)
    print("\n")
# Out:
# Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.
#
#
# Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .
#
#
# Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. Pros-Camera top class - Battery top performed -Chipset no need to say as apple kind -Security as you expect from apple - Display super bright industry leading colour   accuracy and super responsive -Build quality as expect from apple sturdy  premium durable beautiful stylish. -Os most stable os in smartphone industry Cons -No 5G-Display is not based on OLED technology -Charger headphones and 1 apple stic...
#
#
# I'm Really happy with the productDelivery was fast as well..it was a gift for my sister and she loved it so much.
#
#
# ...

# %% [markdown]
# # All of the rating and comments we are extracted, now I am looking for other information that is a name

# %%
comment_box[1].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})

#this is availabled on p, so that I was used p instead of div
# Out:
# [<p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>]

# %%
comment_box[1].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Flipkart Customer'

# %%
for i in comment_box:
    print(i.div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text)    
    print("\n")
# Out:
# Flipkart Customer
#
#
# Flipkart Customer
#
#
# Manish Raghuvanshi
#
#
# George Haokip
#
#
# Jimly  Gogoi
#
#
# Vamshi  Chakrala
#
#
# Chirag Rajput
#
#
# Vishal Dubey
#
#
# vijay hegde
#
#
# Rahul Verma
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19884/4027894772.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text)
#       3     print("\n")
#
# AttributeError: 'NoneType' object has no attribute 'div'
